# %% [markdown]
# ## **Домашнее задание**
#
#
# Используя Python и PostgreSQL, выполните следующие шаги:
#
# 1. **Создание и заполнение таблицы:**
#    - Подключитесь к вашей базе данных PostgreSQL (например, через библиотеку `psycopg2` или `SQLAlchemy`).
#    - Создайте таблицу с именем `apartments`, которая будет содержать 10 столбцов. Пример столбцов:
#      - `id` (SERIAL PRIMARY KEY)
#      - `city` (VARCHAR) – город
#      - `district` (VARCHAR) – район
#      - `address` (VARCHAR) – адрес
#      - `area` (NUMERIC) – площадь квартиры
#      - `rooms` (INT) – количество комнат
#      - `floor` (INT) – этаж
#      - `year_built` (INT) – год постройки
#      - `price` (NUMERIC) – стоимость квартиры
#      - `type` (VARCHAR) – тип (например, новостройка или вторичное жильё)
#
#    - Заполните таблицу 10 строками данных, описывающими различные квартиры с их характеристиками и стоимостью.
#
# 2. **Аналитический запрос с использованием pandas:**
#    - Подключитесь к базе данных через pandas (с использованием `pd.read_sql`).
#    - Выполните SQL-запрос, который выбирает квартиры с ценой ниже 5 000 000.
#    - Выведите полученные данные в виде DataFrame.
#
# **Вместо PostgreSQL допустимо использовать MS SQL или Oracle.**

# %%
import psycopg2

conn_params = {
    'dbname': 'dz_db',
    'user': 'postgres',
    'password': '8520',
    'host': 'localhost',
    'port': '5432'
}

try:
    conn = psycopg2.connect(**conn_params)
    cursor = conn.cursor()

    cursor.execute("DROP TABLE IF EXISTS apartments;")

    create_table = """
    CREATE TABLE apartments (
        id SERIAL PRIMARY KEY,
        city VARCHAR(50),
        district VARCHAR(50),
        address VARCHAR(50),
        area NUMERIC(10,0),
        rooms INT,
        flor INT,
        year_built INT,
        price NUMERIC (10,2),
        type VARCHAR(50)
    );"""
    cursor.execute(create_table)
    conn.commit()

    insert_querty = """
    INSERT INTO apartments (city, district, address, area, rooms, flor, year_built, price, type)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s);
    """
    data = [
        ('Москва', 'Хамовники', 'ул. Пречистенка, 10', 85, 3, 4, 2015, 45000000.00, 'Вторичка'),
        ('Санкт-Петербург', 'Петроградский', 'пр. Добролюбова, 15', 62, 2, 8, 2018, 18500000.00, 'Новостройка'),
        ('Казань', 'Ново-Савиновский', 'ул. Чистопольская, 42', 45, 1, 3, 2010, 7000000.00, 'Вторичка'),
        ('Екатеринбург', 'Академический', 'ул. Краснолесья, 87', 78, 3, 12, 2020, 11000000.00, 'Новостройка'),
        ('Новосибирск', 'Центральный', 'ул. Гоголя, 25', 55, 2, 5, 2005, 6800000.00, 'Вторичка'),
        ('Краснодар', 'Западный', 'ул. Северная, 321', 110, 4, 2, 2023, 15500000.00, 'Новостройка'),
        ('Ростов-на-Дону', 'Ленинский', 'пр. Ворошиловский, 65', 38, 1, 1, 2012, 5200000.00, 'Вторичка'),
        ('Нижний Новгород', 'Нижегородский', 'ул. Рождественская, 22', 92, 3, 6, 1917, 12500000.00, 'Старый фонд'),
        ('Сочи', 'Центральный', 'ул. Театральная, 5', 50, 2, 9, 2019, 17000000.00, 'Новостройка'),
        ('Самара', 'Октябрьский', 'ул. Луначарского, 120', 70, 2, 4, 2008, 6300000.00, 'Вторичка')
    ]
    
    cursor.executemany(insert_querty, data)
    conn.commit()

except Exception as e:
    print("Не созданно потому что:", e)

finally:
    if cursor:
        cursor.close()
    if conn:
        conn.close()

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('postgresql+psycopg2://postgres:8520@localhost:5432/dz_db')

try:
    
    df = pd.read_sql('SELECT * FROM apartments WHERE price < 5000000', engine)

    if df.empty:
        print("Нет данных, соответствующих условию.")
    else:
        print("По запросу найдено:")
        print(df.shape[0], "строк")
        display(df.head()) 

except Exception as e:
    print(f"Произошла ошибка: {e}")
# Out:
# Нет данных, соответствующих условию.
